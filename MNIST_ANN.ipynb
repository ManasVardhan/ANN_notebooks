# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test)=tf.keras.datasets.mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([]) #shows axis lengths
    plt.yticks([])
    plt.imshow(x_train[i])
plt.show()

# %%
model = tf.keras.Sequential([
tf.keras.layers.Flatten(input_shape=(28,28)),
tf.keras.layers.Dense(128,activation = 'relu'),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
r=model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs = 10)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 2.5596 - accuracy: 0.7638 - val_loss: 0.5070 - val_accuracy: 0.8749
# Epoch 2/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.5724 - accuracy: 0.8525 - val_loss: 0.3973 - val_accuracy: 0.9055
# Epoch 3/10
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.4836 - accuracy: 0.8732 - val_loss: 0.3086 - val_accuracy: 0.9316
# Epoch 4/10
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.4172 - accuracy: 0.8931 - val_loss: 0.4613 - val_accuracy: 0.9311
# Epoch 5/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.3837 - accuracy: 0.9019 - val_loss: 0.3203 - val_accuracy: 0.9324
# Epoch 6/10
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.3613 - accuracy: 0.9067 - val_loss: 0.2810 - val_accuracy: 0.9445
# Epoch 7/10
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.3444 - accuracy: 0.9132 - val_loss: 0.2746 - val_accuracy: 0.9430
# Epoch 8/10
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.3247 - accuracy: 0.9172 - val_loss: 0.3047 - val_accuracy: 0.9374
# Epoch 9/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.3300 - accuracy: 0.9183 - val_loss: 0.3022 - val_accuracy: 0.9458
# Epoch 10/10
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3236 - accuracy: 0.9201 - val_loss: 0.3603 - val_accuracy: 0.9370

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
import cv2
import numpy as np

img = cv2.imread('C:\\Users\\Manas Vardhan\\Desktop\\Downloads\\bb.jpg')
res = cv2.resize(img, dsize=(28,28), interpolation=cv2.INTER_CUBIC)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-56-3f413b923421> in <module>
#       3
#       4 img = cv2.imread('C:\\Users\\Manas Vardhan\\Desktop\\Downloads\\bb.jpg')
# ----> 5 res = cv2.resize(img, dsize=(28,28), interpolation=cv2.INTER_CUBIC)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
model.predict('C:\\Users\\Manas Vardhan\\Desktop\\Downloads\\bb.jpg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-a4ec7c7c5220> in <module>
# ----> 1 model.predict('C:\\Users\\Manas Vardhan\\Desktop\\Downloads\\bb.jpg')
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
#     497         steps=steps, callbacks=callbacks, max_queue_size=max_queue_size,
# --> 498         workers=workers, use_multiprocessing=use_multiprocessing, **kwargs)
#     499
#     500
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     424           max_queue_size=max_queue_size,
#     425           workers=workers,
# --> 426           use_multiprocessing=use_multiprocessing)
#     427       total_samples = _get_total_number_of_samples(adapter)
#     428       use_sample = total_samples is not None
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_inputs(model, mode, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     704       max_queue_size=max_queue_size,
#     705       workers=workers,
# --> 706       use_multiprocessing=use_multiprocessing)
#     707
#     708   return adapter
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, shuffle, standardize_function, **kwargs)
#     655     if standardize_function is not None:
#     656       x, y, sample_weights = standardize_function(
# --> 657           x=x, y=y, sample_weight=sample_weights)
#     658
#     659     self._internal_adapter = TensorLikeDataAdapter(
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2381         is_dataset=is_dataset,
#    2382         class_weight=class_weight,
# -> 2383         batch_size=batch_size)
#    2384
#    2385   def _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs,
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2408           feed_input_shapes,
#    2409           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2410           exception_prefix='input')
#    2411
#    2412     # Get typespecs for the input data and sanitize it if necessary.
#
# ~\.conda\envs\Tensor\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     571                            ': expected ' + names[i] + ' to have ' +
#     572                            str(len(shape)) + ' dimensions, but got array '
# --> 573                            'with shape ' + str(data_shape))
#     574         if not check_batch_axis:
#     575           data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected flatten_4_input to have 3 dimensions, but got array with shape ()
